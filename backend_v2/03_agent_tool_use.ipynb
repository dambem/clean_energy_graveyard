# %%
from src.clients import AnthropicClient
from src.processors.repd_processor import REPDProcessor
from main import AppConfig, NimbyAgent
from datetime import datetime

cfg = AppConfig()
client = AnthropicClient(api_key=cfg.api_key, temperature= 0.9)
processor = REPDProcessor()
data = processor.process_pipeline()
agent = NimbyAgent(client=client, processor=processor)
# Out:
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
df = processor.process_pipeline(date=datetime.fromisoformat('2020-08-01'))
df = processor.filter_by_cancelled(df=df)
# Out:
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")
# /Users/dambem/Documents/code/repd_map/backend_v2/src/processors/repd_processor.py:189: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
for _, n in df.iterrows():
    query = processor.get_google_query_string(n)
    print(query)
    val = agent.run_search(context=query)
    print(val)
    break
# Out:
# ('Trecwn Biomass Plant', {'Wales'}, {'Biomass (dedicated)'}), around 2022-04-10 00:00:00
#
#     <ROLE>
#     You are an investigator, based on the context provided, your job is to find an article via websearch that most likely relates to the topic.
#     If multiple are found,
#     </ROLE>
#     <INSTRUCTION>
#     Use the web search tool provided to you to research this.
#     </INSTRUCTION>
#     <CONTEXT>
#     ('Trecwn Biomass Plant', {'Wales'}, {'Biomass (dedicated)'}), around 2022-04-10 00:00:00
#     </CONTEXT>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 query = processor.get_google_query_string(n)
#       3 print(query)
# ----> 4 val = agent.run_search(context=query)
#       5 print(val)
#       6 break
#
# File ~/Documents/code/repd_map/backend_v2/main.py:52, in NimbyAgent.run_search(self, context, prompt_func)
#      47     print(tool_use_blocks)
#      48     message = self.client.call(
#      49         prompt_val,  # Or build on the conversation
#      50         tools='web'
#      51     )
# ---> 52 text_blocks = [block.text for block in message.content if hasattr(block, 'text')]
#      53 return ' '.join(text_blocks)
#
# AttributeError: 'MessageResponse' object has no attribute 'content'
