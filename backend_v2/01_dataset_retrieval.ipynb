# %%
from src.clients import AnthropicClient
from src.processors.repd_processor import REPDProcessor

# %%
processor = REPDProcessor()
df = processor.load()

# %%
df = processor.filter_by_cancelled(df)

# %%
print(df.columns)
# Out:
# Index(['Old Ref ID', 'Ref ID', 'Record Last Updated (dd/mm/yyyy)',
#        'Operator (or Applicant)', 'Site Name', 'Technology Type',
#        'Storage Type', 'Storage Co-location REPD Ref ID',
#        'Installed Capacity (MWelec)', 'Share Community Scheme', 'CHP Enabled',
#        'CfD Allocation Round', 'RO Banding (ROC/MWh)', 'FiT Tariff (p/kWh)',
#        'CfD Capacity (MW)', 'Turbine Capacity', 'No. of Turbines',
#        'Height of Turbines (m)', 'Mounting Type for Solar',
#        'Development Status', 'Development Status (short)',
#        'Are they re-applying (New REPD Ref)',
#        'Are they re-applying (Old REPD Ref) ', 'Address', 'County', 'Region',
#        'Country', 'Post Code', 'X-coordinate', 'Y-coordinate',
#        'Planning Authority', 'Planning Application Reference',
#        'Appeal Reference', 'Secretary of State Reference',
#        'Type of Secretary of State Intervention', 'Judicial Review',
#        'Offshore Wind Round', 'Planning Application Submitted',
#        'Planning Application Withdrawn', 'Planning Permission Refused',
#        'Appeal Lodged', 'Appeal Withdrawn', 'Appeal Refused', 'Appeal Granted',
#        'Planning Permission Granted', 'Secretary of State - Intervened',
#        'Secretary of State - Refusal', 'Secretary of State - Granted',
#        'Planning Permission Expired', 'Under Construction', 'Operational',
#        'Heat Network Ref', 'Solar Site Area (sqm)'],
#       dtype='str')

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of        Old Ref ID    Ref ID Record Last Updated (dd/mm/yyyy)  \
# 1               2       NaN                       20/11/2017
# 4               5       NaN                       29/09/2005
# 5               6  10433191                       13/08/2004
# 6               7  10507360                       29/11/2004
# 7               8  10378302                       23/12/2003
# ...           ...       ...                              ...
# 13264       19216  12861720                       16/09/2025
# 13302       19263  12862856                       29/09/2025
# 13328       19302  12864998                       29/09/2025
# 13333       19326  12865178                       30/09/2025
# 13341       19334  12860855                       26/08/2025
#
#                            Operator (or Applicant)  \
# 1      Orsted (formerly Dong Energy) / Peel Energy
# 4                                          Agrigen
# 5                        Incetec / Border Biofuels
# 6                                           NOVERA
# 7                                Private Developer
# ...                                            ...
# 13264                             AMP Clean Energy
# 13302                             AMP Clean Energy
# 13328                          David Lloyd Leisure
# 13333               Saber Renewable Energy Limited
# 13341          Ford Halewood Transmissions Limited
#
#                                                Site Name      Technology Type  \
# 1                                  Hunterston - cofiring  Biomass (co-firing)
# 4                          Nunn Mills Road Biomass Plant  Biomass (dedicated)
# 5                              Kingmoor Marshalling Yard  Biomass (dedicated)
# 6                    North Wiltshire Biomass Power Plant  Biomass (dedicated)
# 7                                                    NaN  Biomass (dedicated)
# ...                                                  ...                  ...
# 13264  Bringhurst, Orton Goldhay - Energy Storage System              Battery
# 13302  Lewis Road, Perry Hill Lane - Energy Storage F...              Battery
# 13328              David Lloyd Leisure - Solar PV Panels  Solar Photovoltaics
# 13333  Ocado Distribution Centre, South Way - Solar P...  Solar Photovoltaics
# 13341               Revo Project - Renewable Power Plant              Unknown
#
#               Storage Type Storage Co-location REPD Ref ID  \
# 1                      NaN                             NaN
# 4                      NaN                             NaN
# 5                      NaN                             NaN
# 6                      NaN                             NaN
# 7                      NaN                             NaN
# ...                    ...                             ...
# 13264  Stand-alone Storage                             NaN
# 13302  Stand-alone Storage                             NaN
# 13328                  NaN                             NaN
# 13333                  NaN                             NaN
# 13341                  NaN                             NaN
#
#       Installed Capacity (MWelec) Share Community Scheme  ... Appeal Granted  \
# 1                          170.00                    NaN  ...            NaN
# 4                            8.80                    NaN  ...            NaN
# 5                           20.00                    NaN  ...            NaN
# 6                            5.50                    NaN  ...            NaN
# 7                           15.00                    NaN  ...            NaN
# ...                           ...                    ...  ...            ...
# 13264                        0.20                    NaN  ...            NaN
# 13302                        0.20                    NaN  ...            NaN
# 13328                        0.21                    NaN  ...            NaN
# 13333                         NaN                    NaN  ...            NaN
# 13341                        4.00                    NaN  ...            NaN
#
#       Planning Permission Granted Secretary of State - Intervened  \
# 1                             NaN                             NaN
# 4                             NaN                             NaN
# 5                      16/03/2000                             NaN
# 6                             NaN                             NaN
# 7                             NaN                             NaN
# ...                           ...                             ...
# 13264                         NaN                             NaN
# 13302                         NaN                             NaN
# 13328                         NaN                             NaN
# 13333                         NaN                             NaN
# 13341                         NaN                             NaN
#
#       Secretary of State - Refusal Secretary of State - Granted  \
# 1                              NaN                          NaN
# 4                              NaN                          NaN
# 5                              NaN                          NaN
# 6                              NaN                          NaN
# 7                              NaN                          NaN
# ...                            ...                          ...
# 13264                          NaN                          NaN
# 13302                          NaN                          NaN
# 13328                          NaN                          NaN
# 13333                          NaN                          NaN
# 13341                          NaN                          NaN
#
#       Planning Permission Expired Under Construction Operational  \
# 1                             NaN                NaN         NaN
# 4                             NaN                NaN         NaN
# 5                             NaN                NaN         NaN
# 6                             NaN                NaN         NaN
# 7                             NaN                NaN         NaN
# ...                           ...                ...         ...
# 13264                         NaN                NaN         NaN
# 13302                         NaN                NaN         NaN
# 13328                         NaN                NaN         NaN
# 13333                         NaN                NaN         NaN
# 13341                         NaN                NaN         NaN
#
#       Heat Network Ref Solar Site Area (sqm)
# 1                  NaN                   NaN
# 4                  NaN                   NaN
# 5                  NaN                   NaN
# 6                  NaN                   NaN
# 7                  NaN                   NaN
# ...                ...                   ...
# 13264              NaN                   NaN
# 13302              NaN                   NaN
# 13328              NaN                   NaN
# 13333              NaN                   NaN
# 13341              NaN                   NaN
#
# [2558 rows x 53 columns]>
